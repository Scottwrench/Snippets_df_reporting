# %%
import numpy as np
import pandas as pd



#pd.read_csv('fid.csv')  
df=pd.read_csv('/Users/rscottevans/Desktop/Wrench/Mental_guru_Bridger/Factor Loadings Guru.csv')

# %%
col_list=df.columns.tolist() #create a list of column names

# %%
col_list
# Out:
# ['Questions',
#  'FacLoad1',
#  'FacLoad2',
#  'FacLoad3',
#  'FacLoad4',
#  'FacLoad5',
#  'FacLoad6',
#  'FacLoad7',
#  'FacLoad8',
#  'FacLoad9',
#  'FacLoad10',
#  'FacLoad11',
#  'FacLoad12',
#  'FacLoad13',
#  'FacLoad14',
#  'FacLoad15',
#  'FacLoad16',
#  'FacLoad17',
#  'FacLoad18']

# %%
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html

from pandas.plotting import scatter_matrix

# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html

df1=df.iloc[:, lambda df: [1,2,3,4,5]]
scatter_matrix(df1, alpha=0.2, figsize=(12, 12), diagonal="kde");

# %%
df_plot1 = df.plot.scatter(x='FacLoad1',
                      y='FacLoad3',
                      c='DarkBlue', figsize=(12,12))

# %%
df.iloc[:, lambda df: [1,2,3,4,5]]
# Out:
#     FacLoad1  FacLoad2  FacLoad3  FacLoad4  FacLoad5
# 0   0.044264  0.491755 -0.055664  0.083722  0.007883
# 1  -0.317212  0.011520 -0.216632  0.090524 -0.047326
# 2   0.054856 -0.131829  0.557077 -0.033774  0.189274
# 3   0.019608  0.044170  0.013286 -0.083321 -0.118563
# 4  -0.035056  0.716299  0.015156 -0.063619  0.042961
# ..       ...       ...       ...       ...       ...
# 60 -0.204544  0.119286  0.041178 -0.081282 -0.076476
# 61 -0.126094 -0.015854  0.295755  0.072879  0.062998
# 62  0.795315 -0.015806  0.061325  0.077502 -0.108164
# 63 -0.013103 -0.067707 -0.353703 -0.056122 -0.174496
# 64  0.122796 -0.027381 -0.102495  0.296956 -0.048500
#
# [65 rows x 5 columns]
